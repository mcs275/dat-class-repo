# %%
import numpy as np

# %%
var = np.arange(20).reshape(5, 4)

# %%
var

# %%
var.sum()

# %%
# axis 0 operates on the columns
var.sum(axis = 0)

# %%
# axis 1 operates on the rows
var.sum(axis = 1)

# %%
import pandas as pd

# %%
url = r"C:\Users\Jonat\dat-11-15\ClassMaterial\Unit1\data\master.csv"
pd.set_option("display.max_rows", 100)

# %% [markdown]
# Option + Command + C

# %%
df = pd.read_csv(url)

# %%
df.head(30)

# %%
df.values

# %%
df.median()
# Out:
# visitors             17.000000
# holiday               0.000000
# latitude             35.658068
# longitude           139.670038
# reserve_visitors     10.000000
# dtype: float64

# %%
df.head(10).median()
# Out:
# visitors             23.500000
# holiday               0.000000
# latitude             35.658068
# longitude           139.751599
# reserve_visitors           NaN
# dtype: float64

# %%
df.tail(100).median()
# Out:
# visitors             75.000000
# holiday               0.000000
# latitude             35.661777
# longitude           139.704051
# reserve_visitors      7.000000
# dtype: float64

# %%
df['visitors']
# Out:
# 0         25
# 1         32
# 2         29
# 3         22
# 4          6
#           ..
# 252103    49
# 252104    60
# 252105    69
# 252106    31
# 252107    26
# Name: visitors, Length: 252108, dtype: int64

# %%
df[['visitors', 'holiday', 'latitude']].sum()
# Out:
# visitors    5.287653e+06
# holiday     1.277500e+04
# latitude    8.978353e+06
# dtype: float64

# %%
df.iloc[10:100, 2:5]
# Out:
#     visitors day_of_week  holiday
# 10        21      Monday        0
# 11        11     Tuesday        0
# 12        24   Wednesday        0
# 13        21    Thursday        0
# 14        26      Friday        0
# 15         6    Saturday        0
# 16        18   Wednesday        0
# 17        12    Thursday        0
# 18        45      Friday        0
# 19        15    Saturday        0
# 20        19      Monday        0
# 21        15     Tuesday        0
# 22        32   Wednesday        0
# 23         3    Thursday        1
# 24        26      Friday        0
# 25         8    Saturday        0
# 26        14      Monday        0
# 27        15     Tuesday        0
# 28        17   Wednesday        0
# 29        22    Thursday        0
# 30        43      Friday        0
# 31        20    Saturday        0
# 32         7      Monday        0
# 33        16     Tuesday        0
# 34        21   Wednesday        0
# 35        21    Thursday        0
# ...

# %%
df.loc[:, ['visitors', 'holiday', 'latitude']]
# Out:
#         visitors  holiday   latitude
# 0             25        0  35.658068
# 1             32        0  35.658068
# 2             29        0  35.658068
# 3             22        0  35.658068
# 4              6        0  35.658068
# ...          ...      ...        ...
# 252103        49        0  34.695124
# 252104        60        0  34.695124
# 252105        69        0  34.695124
# 252106        31        1  34.695124
# 252107        26        0  34.695124
#
# [252108 rows x 3 columns]

# %%
df[['visitors']]
# Out:
#         visitors
# 0             25
# 1             32
# 2             29
# 3             22
# 4              6
# ...          ...
# 252103        49
# 252104        60
# 252105        69
# 252106        31
# 252107        26
#
# [252108 rows x 1 columns]

# %%
df[['visitors', 'latitude']]
# Out:
# visitors  latitude
# 6         33.589216    731
# 10        35.661777    708
# 4         33.589216    707
# 7         33.589216    684
# 5         33.589216    658
#                       ...
# 50        35.726232      1
# 58        35.726118      1
# 81        43.090850      1
#           38.269076      1
# 877       35.726118      1
# Length: 7945, dtype: int64

# %%
df['visitors'].mean()
# Out:
# 20.973761245180636

# %%
df.loc[:50, ['visitors', 'latitude', 'longitude']]
# Out:
#     visitors   latitude   longitude
# 0         25  35.658068  139.751599
# 1         32  35.658068  139.751599
# 2         29  35.658068  139.751599
# 3         22  35.658068  139.751599
# 4          6  35.658068  139.751599
# 5          9  35.658068  139.751599
# 6         31  35.658068  139.751599
# 7         21  35.658068  139.751599
# 8         18  35.658068  139.751599
# 9         26  35.658068  139.751599
# 10        21  35.658068  139.751599
# 11        11  35.658068  139.751599
# 12        24  35.658068  139.751599
# 13        21  35.658068  139.751599
# 14        26  35.658068  139.751599
# 15         6  35.658068  139.751599
# 16        18  35.658068  139.751599
# 17        12  35.658068  139.751599
# 18        45  35.658068  139.751599
# 19        15  35.658068  139.751599
# 20        19  35.658068  139.751599
# 21        15  35.658068  139.751599
# 22        32  35.658068  139.751599
# 23         3  35.658068  139.751599
# 24        26  35.658068  139.751599
# ...

# %%
df.iloc[:, -5:]
# Out:
#                  genre                          area   latitude   longitude  \
# 0           Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 1           Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 2           Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 3           Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 4           Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# ...                ...                           ...        ...         ...
# 252103  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197852
# 252104  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197852
# 252105  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197852
# 252106  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197852
# 252107  Italian/French  Hyōgo-ken Kōbe-shi Kumoidōri  34.695124  135.197852
#
#         reserve_visitors
# 0                    NaN
# ...

# %%
df['visitors'].mean()
# Out:
# 20.973761245180636

# %%
df[['visitors', 'holiday']].median()
# Out:
# visitors    17.0
# holiday      0.0
# dtype: float64

# %%
df.loc[:5000, 'visitors'].min()
# Out:
# 1

# %%
df.index
# Out:
# RangeIndex(start=0, stop=252108, step=1)

# %%
df = df.set_index('id')

# %%
df.loc[:500, 'visitors']
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-46-51d9635d08f4> in <module>
# ----> 1 df.loc[:500, 'visitors']
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#     871                     # AttributeError for IntervalTree get_value
#     872                     pass
# --> 873             return self._getitem_tuple(key)
#     874         else:
#     875             # we by definition only have the 0th axis
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_tuple(self, tup)
#    1042     def _getitem_tuple(self, tup: Tuple):
#    1043         try:
# -> 1044             return self._getitem_lowerdim(tup)
#    1045         except IndexingError:
#    1046             pass
#
# ~\anaconda3\lib\site-packages\pandas\core\indexing.py in _getitem_lowerdim(self, tup)
#     808                     return section
# ...

# %%
df.loc['air_ba937bf13d40fb24', 'visitors']
# Out:
# id
# air_ba937bf13d40fb24    25
# air_ba937bf13d40fb24    32
# air_ba937bf13d40fb24    29
# air_ba937bf13d40fb24    22
# air_ba937bf13d40fb24     6
#                         ..
# air_ba937bf13d40fb24    11
# air_ba937bf13d40fb24    11
# air_ba937bf13d40fb24    14
# air_ba937bf13d40fb24    40
# air_ba937bf13d40fb24    23
# Name: visitors, Length: 391, dtype: int64

# %%
df['visitors'].head(5000).min()
# Out:
# 1

# %%
df.iloc[:, -4:].mode()
# Out:
#                              area   latitude   longitude  reserve_visitors
# 0  Fukuoka-ken Fukuoka-shi Daimyō  33.589216  130.392813               2.0

# %%
df.iloc[:250, -3:].mean()
# Out:
# visitors    24.912
# dtype: float64

# %%
df.sort_values(by = 'visit_date', ascending = False)
# Out:
#                       visit_date  visitors day_of_week  holiday  \
# id
# air_396166d47733d5c9  2017-04-22        51    Saturday        0
# air_fab092c35776a9b1  2017-04-22        16    Saturday        0
# air_d5e0a20370c325c7  2017-04-22        52    Saturday        0
# air_eb5788dba285e725  2017-04-22        42    Saturday        0
# air_61de73b097513f58  2017-04-22        13    Saturday        0
# ...                          ...       ...         ...      ...
# air_71903025d39a4571  2016-01-01         5      Friday        1
# air_60a7057184ec7ec7  2016-01-01        64      Friday        1
# air_d97dabf7aae60da5  2016-01-01       102      Friday        1
# air_81c5dff692063446  2016-01-01         7      Friday        1
# air_d0e8a085d8dc83aa  2016-01-01         8      Friday        1
#
#                                      genre  \
# id
# air_396166d47733d5c9  Yakiniku/Korean food
# air_fab092c35776a9b1           Cafe/Sweets
# air_d5e0a20370c325c7           Cafe/Sweets
# ...

# %%
df[df['holiday'] > 0]
# Out:
#                       visit_date  visitors day_of_week  holiday  \
# id
# air_ba937bf13d40fb24  2016-02-11         3    Thursday        1
# air_ba937bf13d40fb24  2016-08-11         2    Thursday        1
# air_ba937bf13d40fb24  2016-08-13        21    Saturday        1
# air_ba937bf13d40fb24  2016-09-22        21    Thursday        1
# air_ba937bf13d40fb24  2016-11-03        12    Thursday        1
# ...                          ...       ...         ...      ...
# air_8e8f42f047537154  2017-03-20        32      Monday        1
# air_bb4ff06cd661ee9b  2017-03-20        40      Monday        1
# air_cf5ab75a0afb8af9  2017-03-20        63      Monday        1
# air_1c0b150f9e696a5f  2017-03-20       136      Monday        1
# air_a17f0778617c76e2  2017-03-20        31      Monday        1
#
#                                              genre  \
# id
# air_ba937bf13d40fb24                    Dining bar
# air_ba937bf13d40fb24                    Dining bar
# ...

# %%
df = df.reset_index()

# %%
df[df['holiday'] == 1]
# Out:
#                           id  visit_date  visitors day_of_week  holiday  \
# 23      air_ba937bf13d40fb24  2016-02-11         3    Thursday        1
# 174     air_ba937bf13d40fb24  2016-08-11         2    Thursday        1
# 176     air_ba937bf13d40fb24  2016-08-13        21    Saturday        1
# 205     air_ba937bf13d40fb24  2016-09-22        21    Thursday        1
# 241     air_ba937bf13d40fb24  2016-11-03        12    Thursday        1
# ...                      ...         ...       ...         ...      ...
# 251869  air_8e8f42f047537154  2017-03-20        32      Monday        1
# 251935  air_bb4ff06cd661ee9b  2017-03-20        40      Monday        1
# 251988  air_cf5ab75a0afb8af9  2017-03-20        63      Monday        1
# 252039  air_1c0b150f9e696a5f  2017-03-20       136      Monday        1
# 252106  air_a17f0778617c76e2  2017-03-20        31      Monday        1
#
#                                genre                                area  \
# ...

# %%
df.loc[(df['holiday'] == 1) & (df['day_of_week'] == 'Wednesday'), :]
# Out:
#                           id  visit_date  visitors day_of_week  holiday  \
# 259     air_ba937bf13d40fb24  2016-11-23         8   Wednesday        1
# 679     air_25e9888d30b386df  2016-05-04        15   Wednesday        1
# 1348    air_64d4491ad8cdb1c6  2016-11-23         7   Wednesday        1
# 1490    air_64d4491ad8cdb1c6  2016-05-04        12   Wednesday        1
# 1712    air_ee3a01f0c71a769f  2016-11-23        30   Wednesday        1
# ...                      ...         ...       ...         ...      ...
# 250222  air_947eb2cae4f3e8f2  2016-11-23        22   Wednesday        1
# 250409  air_8d61f49aa0373492  2016-11-23        48   Wednesday        1
# 250595  air_90ed0a2f24755533  2016-11-23        57   Wednesday        1
# 250765  air_0164b9927d20bcc3  2016-11-23         3   Wednesday        1
# 251021  air_a257c9749d8d0ff6  2016-11-23        28   Wednesday        1
#
#                                genre                                     area  \
# ...

# %%
df[df['visitors'].between(10, 20, inclusive = False)]
# Out:
#                           id  visit_date  visitors day_of_week  holiday  \
# 8       air_ba937bf13d40fb24  2016-01-22        18      Friday        0
# 11      air_ba937bf13d40fb24  2016-01-26        11     Tuesday        0
# 16      air_ba937bf13d40fb24  2016-02-03        18   Wednesday        0
# 17      air_ba937bf13d40fb24  2016-02-04        12    Thursday        0
# 19      air_ba937bf13d40fb24  2016-02-06        15    Saturday        0
# ...                      ...         ...       ...         ...      ...
# 252063  air_a17f0778617c76e2  2017-03-09        18    Thursday        0
# 252066  air_a17f0778617c76e2  2017-03-12        19      Sunday        0
# 252070  air_a17f0778617c76e2  2017-03-16        17    Thursday        0
# 252099  air_a17f0778617c76e2  2017-04-17        19      Monday        0
# 252100  air_a17f0778617c76e2  2017-04-18        11     Tuesday        0
#
#                  genre                          area   latitude   longitude  \
# ...

# %%
df[df['day_of_week'] == 'Monday']['visitors'].mean()
# Out:
# 17.177009027207877

# %%
df[(df['day_of_week'] == 'Saturday') | (df['day_of_week'] == 'Sunday')]['visitors'].mean()
# Out:
# 25.256869738495084

# %%
df[df['day_of_week'].isin(['Saturday', 'Sunday'])]['visitors'].mean()
# Out:
# 25.256869738495084

# %%
query = df['day_of_week'].isin(['Saturday', 'Sunday'])

# %%
df[query]
# Out:
#                           id  visit_date  visitors day_of_week  holiday  \
# 3       air_ba937bf13d40fb24  2016-01-16        22    Saturday        0
# 9       air_ba937bf13d40fb24  2016-01-23        26    Saturday        0
# 15      air_ba937bf13d40fb24  2016-01-30         6    Saturday        0
# 19      air_ba937bf13d40fb24  2016-02-06        15    Saturday        0
# 25      air_ba937bf13d40fb24  2016-02-13         8    Saturday        0
# ...                      ...         ...       ...         ...      ...
# 252097  air_a17f0778617c76e2  2017-04-15        61    Saturday        0
# 252098  air_a17f0778617c76e2  2017-04-16        26      Sunday        0
# 252104  air_a17f0778617c76e2  2017-04-22        60    Saturday        0
# 252105  air_a17f0778617c76e2  2017-03-26        69      Sunday        0
# 252107  air_a17f0778617c76e2  2017-04-09        26      Sunday        0
#
#                  genre                          area   latitude   longitude  \
# ...

# %%
df[df['holiday'] == 1]['visitors'].mean()
# Out:
# 23.703326810176126

# %%
idx = df[df['genre'] == 'Dining bar']['visitors'].idxmax()

# %%
df.iloc[idx]
# Out:
# id                           air_c6aa2efba0ffc8eb
# visit_date                             2017-01-23
# visitors                                      348
# day_of_week                                Monday
# holiday                                         0
# genre                                  Dining bar
# area                Tōkyō-to Adachi-ku Chūōhonchō
# latitude                                  35.7757
# longitude                                 139.804
# reserve_visitors                               25
# Name: 245791, dtype: object

# %%
idx = df[df['holiday'] == 1]['reserve_visitors'].idxmax()

# %%
idx = df[df['holiday'] == 1]['reserve_visitors'].idxmax()

# %%
idx
# Out:
# 1503

# %%
df.iloc[idx]
# Out:
# id                          air_64d4491ad8cdb1c6
# visit_date                            2016-12-30
# visitors                                      23
# day_of_week                               Friday
# holiday                                        1
# genre                                 Dining bar
# area                Tōkyō-to Minato-ku Shibakōen
# latitude                                 35.6581
# longitude                                139.752
# reserve_visitors                              58
# Name: 1503, dtype: object

# %%
df.iloc[idx]
# Out:
# id                          air_64d4491ad8cdb1c6
# visit_date                            2016-12-30
# visitors                                      23
# day_of_week                               Friday
# holiday                                        1
# genre                                 Dining bar
# area                Tōkyō-to Minato-ku Shibakōen
# latitude                                 35.6581
# longitude                                139.752
# reserve_visitors                              58
# Name: 1503, dtype: object

# %%
df['holiday']
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 252103    0
# 252104    0
# 252105    0
# 252106    1
# 252107    0
# Name: holiday, Length: 252108, dtype: int64

# %%
df.holiday
# Out:
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#          ..
# 252103    0
# 252104    0
# 252105    0
# 252106    1
# 252107    0
# Name: holiday, Length: 252108, dtype: int64

# %%
index = df[df['visitors'] > 10]

# %%
col_index = df.isnull().sum() > 0

# %%
df.loc[index, col_index]
# Out:
#         reserve_visitors
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 6                    NaN
# ...                  ...
# 252103               6.0
# 252104              37.0
# 252105              35.0
# 252106               3.0
# 252107              32.0
#
# [174954 rows x 1 columns]

# %%
df.iloc[2:10, [1, 2, 4]]
# Out:
#    visit_date  visitors  holiday
# 2  2016-01-15        29        0
# 3  2016-01-16        22        0
# 4  2016-01-18         6        0
# 5  2016-01-19         9        0
# 6  2016-01-20        31        0
# 7  2016-01-21        21        0
# 8  2016-01-22        18        0
# 9  2016-01-23        26        0
