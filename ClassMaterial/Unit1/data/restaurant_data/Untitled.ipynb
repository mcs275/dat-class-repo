# %%
import pandas as pd

# %%
reservations = pd.read_csv('air_reserve.csv')

# %%
stores = pd.read_csv('air_store_info.csv')

# %%
visits = pd.read_csv('air_visit_data.csv')

# %%
dates = pd.read_csv('date_info.csv')
dates['calendar_date'] = pd.to_datetime(dates['calendar_date'])

# %%
reservations['visit_datetime'] = pd.to_datetime(reservations['visit_datetime']).dt.date
reservations['visit_datetime'] = pd.to_datetime(reservations['visit_datetime'])

# %%
visits['visit_date'] = pd.to_datetime(visits['visit_date'])

# %%
reservations = reservations.merge(dates, left_on = 'visit_datetime', right_on = 'calendar_date', how = 'left')

# %%
reservations = reservations.groupby(['air_store_id', 'visit_datetime'])[['reserve_visitors']].sum().reset_index()

# %%
reservations
# Out:
#                air_store_id visit_datetime  reserve_visitors calendar_date  \
# 0      air_00a91d42b08b08d9     2016-10-31                 2    2016-10-31
# 1      air_00a91d42b08b08d9     2016-12-05                 9    2016-12-05
# 2      air_00a91d42b08b08d9     2016-12-14                18    2016-12-14
# 3      air_00a91d42b08b08d9     2016-12-17                 2    2016-12-17
# 4      air_00a91d42b08b08d9     2016-12-20                 4    2016-12-20
# ...                     ...            ...               ...           ...
# 29825  air_fea5dc9594450608     2017-04-22                 2    2017-04-22
# 29826  air_fea5dc9594450608     2017-04-25                 2    2017-04-25
# 29827  air_fea5dc9594450608     2017-04-28                 3    2017-04-28
# 29828  air_fea5dc9594450608     2017-05-20                 6    2017-05-20
# 29829  air_fee8dcf4d619598e     2017-01-09                 5    2017-01-09
#
#       day_of_week  holiday_flg
# 0          Monday            0
# ...

# %%
visits = visits.merge(reservations, left_on = ['air_store_id', 'visit_date'], right_on = ['air_store_id', 'visit_datetime'], how = 'left')

# %%
visits.head(20)
# Out:
#             air_store_id visit_date  visitors visit_datetime  \
# 0   air_ba937bf13d40fb24 2016-01-13        25            NaT
# 1   air_ba937bf13d40fb24 2016-01-14        32            NaT
# 2   air_ba937bf13d40fb24 2016-01-15        29            NaT
# 3   air_ba937bf13d40fb24 2016-01-16        22            NaT
# 4   air_ba937bf13d40fb24 2016-01-18         6            NaT
# 5   air_ba937bf13d40fb24 2016-01-19         9            NaT
# 6   air_ba937bf13d40fb24 2016-01-20        31            NaT
# 7   air_ba937bf13d40fb24 2016-01-21        21            NaT
# 8   air_ba937bf13d40fb24 2016-01-22        18            NaT
# 9   air_ba937bf13d40fb24 2016-01-23        26            NaT
# 10  air_ba937bf13d40fb24 2016-01-25        21            NaT
# 11  air_ba937bf13d40fb24 2016-01-26        11            NaT
# 12  air_ba937bf13d40fb24 2016-01-27        24            NaT
# 13  air_ba937bf13d40fb24 2016-01-28        21            NaT
# ...

# %%
visits['reserve_visitors'].isnull().sum()
# Out:
# 224044
