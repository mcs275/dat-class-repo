# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('/Users/mcs275/dat-11-15/ClassMaterial/Unit1/data/master.csv')

# %%
df.columns
# Out:
# Index(['id', 'visit_date', 'visitors', 'day_of_week', 'holiday', 'genre',
#        'area', 'latitude', 'longitude', 'reserve_visitors'],
#       dtype='object')

# %%
df
# Out:
#                           id  visit_date  visitors day_of_week  holiday  \
# 0       air_ba937bf13d40fb24  2016-01-13        25   Wednesday        0
# 1       air_ba937bf13d40fb24  2016-01-14        32    Thursday        0
# 2       air_ba937bf13d40fb24  2016-01-15        29      Friday        0
# 3       air_ba937bf13d40fb24  2016-01-16        22    Saturday        0
# 4       air_ba937bf13d40fb24  2016-01-18         6      Monday        0
# ...                      ...         ...       ...         ...      ...
# 252103  air_a17f0778617c76e2  2017-04-21        49      Friday        0
# 252104  air_a17f0778617c76e2  2017-04-22        60    Saturday        0
# 252105  air_a17f0778617c76e2  2017-03-26        69      Sunday        0
# 252106  air_a17f0778617c76e2  2017-03-20        31      Monday        1
# 252107  air_a17f0778617c76e2  2017-04-09        26      Sunday        0
#
#                  genre                          area   latitude   longitude  \
# ...

# %%
pwd
# Out:
# '/Users/mcs275/dat-class-repo'

# %%
##loc means look things up by their labels
##index in df is a numeric range so can you use numbers

# %%
df.loc[10:100, 'visitors']
# Out:
# 10     21
# 11     11
# 12     24
# 13     21
# 14     26
#        ..
# 96     24
# 97     30
# 98     45
# 99     48
# 100    11
# Name: visitors, Length: 91, dtype: int64

# %%
df.loc[10:100,['visitors','holiday']]
# Out:
#      visitors  holiday
# 10         21        0
# 11         11        0
# 12         24        0
# 13         21        0
# 14         26        0
# ..        ...      ...
# 96         24        0
# 97         30        0
# 98         45        0
# 99         48        0
# 100        11        0
#
# [91 rows x 2 columns]

# %%
##df['visitors'][:50]
##this will create copy of the data so only do this to look at the data
# Out:
# 0     25
# 1     32
# 2     29
# 3     22
# 4      6
# 5      9
# 6     31
# 7     21
# 8     18
# 9     26
# 10    21
# 11    11
# 12    24
# 13    21
# 14    26
# 15     6
# 16    18
# 17    12
# 18    45
# 19    15
# 20    19
# 21    15
# 22    32
# 23     3
# 24    26
# 25     8
# 26    14
# 27    15
# 28    17
# 29    22
# 30    43
# 31    20
# 32     7
# 33    16
# 34    21
# 35    21
# 36    32
# 37    23
# 38    22
# 39    19
# 40    21
# 41    20
# 42    37
# 43    13
# 44    11
# 45     8
# 46    23
# 47    31
# 48    37
# 49    25
# Name: visitors, dtype: int64

# %%
##iloc is based off of numerical lookup

# %%
df.iloc[10:100, :5]
# Out:
#                       id  visit_date  visitors day_of_week  holiday
# 10  air_ba937bf13d40fb24  2016-01-25        21      Monday        0
# 11  air_ba937bf13d40fb24  2016-01-26        11     Tuesday        0
# 12  air_ba937bf13d40fb24  2016-01-27        24   Wednesday        0
# 13  air_ba937bf13d40fb24  2016-01-28        21    Thursday        0
# 14  air_ba937bf13d40fb24  2016-01-29        26      Friday        0
# ..                   ...         ...       ...         ...      ...
# 95  air_ba937bf13d40fb24  2016-05-10        14     Tuesday        0
# 96  air_ba937bf13d40fb24  2016-05-11        24   Wednesday        0
# 97  air_ba937bf13d40fb24  2016-05-12        30    Thursday        0
# 98  air_ba937bf13d40fb24  2016-05-13        45      Friday        0
# 99  air_ba937bf13d40fb24  2016-05-14        48    Saturday        0
#
# [90 rows x 5 columns]

# %%
# to get specific columns, pass them as a list i.e. [2,4,6]

# %%
df.iloc[10:11, [2,4,6]]
# Out:
#     visitors  holiday                          area
# 10        21        0  Tōkyō-to Minato-ku Shibakōen

# %%
##select based off some type of condition
##loc can ook up by true and false

# %%
df['holiday'] == 1
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 252103    False
# 252104    False
# 252105    False
# 252106     True
# 252107    False
# Name: holiday, Length: 252108, dtype: bool

# %%
df[df['holiday'] == 1]
# Out:
#                           id  visit_date  visitors day_of_week  holiday  \
# 23      air_ba937bf13d40fb24  2016-02-11         3    Thursday        1
# 174     air_ba937bf13d40fb24  2016-08-11         2    Thursday        1
# 176     air_ba937bf13d40fb24  2016-08-13        21    Saturday        1
# 205     air_ba937bf13d40fb24  2016-09-22        21    Thursday        1
# 241     air_ba937bf13d40fb24  2016-11-03        12    Thursday        1
# ...                      ...         ...       ...         ...      ...
# 251869  air_8e8f42f047537154  2017-03-20        32      Monday        1
# 251935  air_bb4ff06cd661ee9b  2017-03-20        40      Monday        1
# 251988  air_cf5ab75a0afb8af9  2017-03-20        63      Monday        1
# 252039  air_1c0b150f9e696a5f  2017-03-20       136      Monday        1
# 252106  air_a17f0778617c76e2  2017-03-20        31      Monday        1
#
#                                genre                                area  \
# ...

# %%
df.isnull()
# Out:
#            id  visit_date  visitors  day_of_week  holiday  genre   area  \
# 0       False       False     False        False    False  False  False
# 1       False       False     False        False    False  False  False
# 2       False       False     False        False    False  False  False
# 3       False       False     False        False    False  False  False
# 4       False       False     False        False    False  False  False
# ...       ...         ...       ...          ...      ...    ...    ...
# 252103  False       False     False        False    False  False  False
# 252104  False       False     False        False    False  False  False
# 252105  False       False     False        False    False  False  False
# 252106  False       False     False        False    False  False  False
# 252107  False       False     False        False    False  False  False
#
#         latitude  longitude  reserve_visitors
# 0          False      False              True
# ...

# %%
##any row with any null?
df.isnull().sum(axis =1 )>0
# Out:
# 0          True
# 1          True
# 2          True
# 3          True
# 4          True
#           ...
# 252103    False
# 252104    False
# 252105    False
# 252106    False
# 252107    False
# Length: 252108, dtype: bool

# %%
df.loc[df.isnull().sum(axis =1 )>0, :]
# Out:
#                           id  visit_date  visitors day_of_week  holiday  \
# 0       air_ba937bf13d40fb24  2016-01-13        25   Wednesday        0
# 1       air_ba937bf13d40fb24  2016-01-14        32    Thursday        0
# 2       air_ba937bf13d40fb24  2016-01-15        29      Friday        0
# 3       air_ba937bf13d40fb24  2016-01-16        22    Saturday        0
# 4       air_ba937bf13d40fb24  2016-01-18         6      Monday        0
# ...                      ...         ...       ...         ...      ...
# 252087  air_a17f0778617c76e2  2017-04-04        10     Tuesday        0
# 252092  air_a17f0778617c76e2  2017-04-10        28      Monday        0
# 252099  air_a17f0778617c76e2  2017-04-17        19      Monday        0
# 252100  air_a17f0778617c76e2  2017-04-18        11     Tuesday        0
# 252101  air_a17f0778617c76e2  2017-04-19        25   Wednesday        0
#
#                  genre                          area   latitude   longitude  \
# ...

# %%
df.columns
# Out:
# Index(['id', 'visit_date', 'visitors', 'day_of_week', 'holiday', 'genre',
#        'area', 'latitude', 'longitude', 'reserve_visitors'],
#       dtype='object')

# %%
#sum down the columns (any column with a null)? 
df.isnull().sum(axis = 0) >0
# Out:
# id                  False
# visit_date          False
# visitors            False
# day_of_week         False
# holiday             False
# genre               False
# area                False
# latitude            False
# longitude           False
# reserve_visitors     True
# dtype: bool

# %%
#select all the oclumns with missing values
#axis=0 performs operation down the column 
#axis =1 is across the rows
#so looking for columns where there is at least one null?
df.loc[:, df.isnull().sum(axis = 0) >0]
# Out:
#         reserve_visitors
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 252103               6.0
# 252104              37.0
# 252105              35.0
# 252106               3.0
# 252107              32.0
#
# [252108 rows x 1 columns]

# %%
df.isnull()
# Out:
#            id  visit_date  visitors  day_of_week  holiday  genre   area  \
# 0       False       False     False        False    False  False  False
# 1       False       False     False        False    False  False  False
# 2       False       False     False        False    False  False  False
# 3       False       False     False        False    False  False  False
# 4       False       False     False        False    False  False  False
# ...       ...         ...       ...          ...      ...    ...    ...
# 252103  False       False     False        False    False  False  False
# 252104  False       False     False        False    False  False  False
# 252105  False       False     False        False    False  False  False
# 252106  False       False     False        False    False  False  False
# 252107  False       False     False        False    False  False  False
#
#         latitude  longitude  reserve_visitors
# 0          False      False              True
# ...

# %%
df.isnull().sum(axis =0) >0
# Out:
# id                  False
# visit_date          False
# visitors            False
# day_of_week         False
# holiday             False
# genre               False
# area                False
# latitude            False
# longitude           False
# reserve_visitors     True
# dtype: bool

# %%
# ?df.isnull()
# Out:
# Object `df.isnull()` not found.

# %%
# ?pd.Series.value_counts()
# Out:
# Object `pd.Series.value_counts()` not found.

# %%
# ?pd.Series.value_counts

# %%
pd.Series.value_counts(['latitude'])
# Out:
# latitude    1
# dtype: int64

# %%
df['day_of_week'].value_counts()
# Out:
# Friday       40351
# Saturday     39262
# Thursday     37996
# Wednesday    36811
# Tuesday      36015
# Monday       31682
# Sunday       29991
# Name: day_of_week, dtype: int64

# %%
df.nunique().sort_values(ascending=False)
# Out:
# id                  829
# visit_date          478
# visitors            204
# latitude            108
# longitude           108
# area                103
# reserve_visitors     49
# genre                14
# day_of_week           7
# holiday               2
# dtype: int64

# %%
# ?pd.sort_values
# Out:
# Object `pd.sort_values` not found.

# %%
df.loc[:, df.isnull().sum() > 0]
##returns column that is only column with null values, which is reserve visitors
# Out:
#         reserve_visitors
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 252103               6.0
# 252104              37.0
# 252105              35.0
# 252106               3.0
# 252107              32.0
#
# [252108 rows x 1 columns]

# %%
df.iloc[252105]
# Out:
# id                          air_a17f0778617c76e2
# visit_date                            2017-03-26
# visitors                                      69
# day_of_week                               Sunday
# holiday                                        0
# genre                             Italian/French
# area                Hyōgo-ken Kōbe-shi Kumoidōri
# latitude                               34.695124
# longitude                             135.197852
# reserve_visitors                            35.0
# Name: 252105, dtype: object

# %%
df.isnull().any()
# Out:
# id                  False
# visit_date          False
# visitors            False
# day_of_week         False
# holiday             False
# genre               False
# area                False
# latitude            False
# longitude           False
# reserve_visitors     True
# dtype: bool

# %%
df.loc[~df.isnull().any(axis =1), :]
# Out:
#                           id  visit_date  visitors day_of_week  holiday  \
# 11      air_ba937bf13d40fb24  2016-01-26        11     Tuesday        0
# 21      air_ba937bf13d40fb24  2016-02-09        15     Tuesday        0
# 24      air_ba937bf13d40fb24  2016-02-12        26      Friday        0
# 25      air_ba937bf13d40fb24  2016-02-13         8    Saturday        0
# 37      air_ba937bf13d40fb24  2016-02-27        23    Saturday        0
# ...                      ...         ...       ...         ...      ...
# 252103  air_a17f0778617c76e2  2017-04-21        49      Friday        0
# 252104  air_a17f0778617c76e2  2017-04-22        60    Saturday        0
# 252105  air_a17f0778617c76e2  2017-03-26        69      Sunday        0
# 252106  air_a17f0778617c76e2  2017-03-20        31      Monday        1
# 252107  air_a17f0778617c76e2  2017-04-09        26      Sunday        0
#
#                  genre                          area   latitude   longitude  \
# ...

# %%
df['holiday'].value_counts()
# Out:
# 0    239333
# 1     12775
# Name: holiday, dtype: int64

# %%
df.columns.tolist()
# Out:
# ['id',
#  'visit_date',
#  'visitors',
#  'day_of_week',
#  'holiday',
#  'genre',
#  'area',
#  'latitude',
#  'longitude',
#  'reserve_visitors']

# %%
df.sort_values(by = 'visitors', ascending = False)
# Out:
#                           id  visit_date  visitors day_of_week  holiday  \
# 35102   air_cfdeb326418194ff  2017-03-08       877   Wednesday        0
# 225377  air_8c3175aa5e4fc569  2017-04-18       777     Tuesday        0
# 158627  air_f2985de32bb792e0  2016-07-10       675      Sunday        0
# 206339  air_eca5e0064dc9314a  2016-08-30       627     Tuesday        0
# 61432   air_43d577e0c9460e64  2016-01-24       514      Sunday        0
# ...                      ...         ...       ...         ...      ...
# 244631  air_0ead98dd07e7a82a  2017-02-28         1     Tuesday        0
# 174055  air_aed3a8b49abe4a48  2017-02-17         1      Friday        0
# 64282   air_f0c7272956e62f12  2016-02-05         1      Friday        0
# 149049  air_6873982b9e19c7ad  2017-03-03         1      Friday        0
# 237362  air_bbe1c1a47e09f161  2016-11-20         1      Sunday        0
#
#                    genre                                    area   latitude  \
# ...

# %%
df.sort_values(by = ['visit_date','id'], ascending = [True, False])
# Out:
#                           id  visit_date  visitors day_of_week  holiday  \
# 27361   air_fe22ef5a9cbef123  2016-01-01        21      Friday        1
# 82604   air_fab092c35776a9b1  2016-01-01        19      Friday        1
# 108467  air_f690c42545146e0a  2016-01-01         7      Friday        1
# 87077   air_f26f36ec4dc5adb0  2016-01-01        64      Friday        1
# 21700   air_efc80d3f96b3aff7  2016-01-01        10      Friday        1
# ...                      ...         ...       ...         ...      ...
# 200523  air_034a3d5b40d5b1b1  2017-04-22        35    Saturday        0
# 245987  air_0328696196e46f18  2017-04-22         8    Saturday        0
# 99582   air_0241aa3964b7f861  2017-04-22        13    Saturday        0
# 250874  air_0164b9927d20bcc3  2017-04-22         6    Saturday        0
# 167062  air_00a91d42b08b08d9  2017-04-22        18    Saturday        0
#
#                  genre                                   area   latitude  \
# ...

# %%
df.loc[df.isnull().sum(axis =1) > 0, df.isnull().sum(axis = 0) > 0]
# Out:
#         reserve_visitors
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 252087               NaN
# 252092               NaN
# 252099               NaN
# 252100               NaN
# 252101               NaN
#
# [143714 rows x 1 columns]

# %%
df.isnull().sum(axis = 1)
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 252103    0
# 252104    0
# 252105    0
# 252106    0
# 252107    0
# Length: 252108, dtype: int64

# %%
df[df.isnull().sum(axis = 1) == 0]
# Out:
#                           id  visit_date  visitors day_of_week  holiday  \
# 11      air_ba937bf13d40fb24  2016-01-26        11     Tuesday        0
# 21      air_ba937bf13d40fb24  2016-02-09        15     Tuesday        0
# 24      air_ba937bf13d40fb24  2016-02-12        26      Friday        0
# 25      air_ba937bf13d40fb24  2016-02-13         8    Saturday        0
# 37      air_ba937bf13d40fb24  2016-02-27        23    Saturday        0
# ...                      ...         ...       ...         ...      ...
# 252103  air_a17f0778617c76e2  2017-04-21        49      Friday        0
# 252104  air_a17f0778617c76e2  2017-04-22        60    Saturday        0
# 252105  air_a17f0778617c76e2  2017-03-26        69      Sunday        0
# 252106  air_a17f0778617c76e2  2017-03-20        31      Monday        1
# 252107  air_a17f0778617c76e2  2017-04-09        26      Sunday        0
#
#                  genre                          area   latitude   longitude  \
# ...

# %%
df.notnull().all(axis =1)
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 252103     True
# 252104     True
# 252105     True
# 252106     True
# 252107     True
# Length: 252108, dtype: bool

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 252103    False
# 252104    False
# 252105    False
# 252106    False
# 252107    False
# Length: 252108, dtype: bool

# %%
df[df.duplicated(subset = ['visit_date','visitors'], keep = False)]
# Out:
#                           id  visit_date  visitors day_of_week  holiday  \
# 0       air_ba937bf13d40fb24  2016-01-13        25   Wednesday        0
# 1       air_ba937bf13d40fb24  2016-01-14        32    Thursday        0
# 2       air_ba937bf13d40fb24  2016-01-15        29      Friday        0
# 3       air_ba937bf13d40fb24  2016-01-16        22    Saturday        0
# 4       air_ba937bf13d40fb24  2016-01-18         6      Monday        0
# ...                      ...         ...       ...         ...      ...
# 252102  air_a17f0778617c76e2  2017-04-20        22    Thursday        0
# 252103  air_a17f0778617c76e2  2017-04-21        49      Friday        0
# 252105  air_a17f0778617c76e2  2017-03-26        69      Sunday        0
# 252106  air_a17f0778617c76e2  2017-03-20        31      Monday        1
# 252107  air_a17f0778617c76e2  2017-04-09        26      Sunday        0
#
#                  genre                          area   latitude   longitude  \
# ...

# %%
df[df.duplicated()]
# Out:
# Empty DataFrame
# Columns: [id, visit_date, visitors, day_of_week, holiday, genre, area, latitude, longitude, reserve_visitors]
# Index: []

# %%
df.select_dtypes(include = np.object)
# Out:
# <ipython-input-112-5bc23d71409b>:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   df.select_dtypes(include = np.object)
#                           id  visit_date day_of_week           genre  \
# 0       air_ba937bf13d40fb24  2016-01-13   Wednesday      Dining bar
# 1       air_ba937bf13d40fb24  2016-01-14    Thursday      Dining bar
# 2       air_ba937bf13d40fb24  2016-01-15      Friday      Dining bar
# 3       air_ba937bf13d40fb24  2016-01-16    Saturday      Dining bar
# 4       air_ba937bf13d40fb24  2016-01-18      Monday      Dining bar
# ...                      ...         ...         ...             ...
# 252103  air_a17f0778617c76e2  2017-04-21      Friday  Italian/French
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252108 entries, 0 to 252107
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                252108 non-null  object
#  1   visit_date        252108 non-null  object
#  2   visitors          252108 non-null  int64
#  3   day_of_week       252108 non-null  object
#  4   holiday           252108 non-null  int64
#  5   genre             252108 non-null  object
#  6   area              252108 non-null  object
#  7   latitude          252108 non-null  float64
#  8   longitude         252108 non-null  float64
#  9   reserve_visitors  108394 non-null  float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 19.2+ MB

# %%
num_cols = df.select_dtypes(include = np.number).columns.tolist()

# %%
num_cols
# Out:
# ['visitors', 'holiday', 'latitude', 'longitude', 'reserve_visitors']

# %%
df.isnull()
# Out:
#            id  visit_date  visitors  day_of_week  holiday  genre   area  \
# 0       False       False     False        False    False  False  False
# 1       False       False     False        False    False  False  False
# 2       False       False     False        False    False  False  False
# 3       False       False     False        False    False  False  False
# 4       False       False     False        False    False  False  False
# ...       ...         ...       ...          ...      ...    ...    ...
# 252103  False       False     False        False    False  False  False
# 252104  False       False     False        False    False  False  False
# 252105  False       False     False        False    False  False  False
# 252106  False       False     False        False    False  False  False
# 252107  False       False     False        False    False  False  False
#
#         latitude  longitude  reserve_visitors
# 0          False      False              True
# ...

# %%
# ?pd.fillna
# Out:
# Object `pd.fillna` not found.

# %%
# ?fillna
# Out:
# Object `fillna` not found.

# %%
?

# %%
num_cols
# Out:
# ['visitors', 'holiday', 'latitude', 'longitude', 'reserve_visitors']

# %%
##select numeric columns from df
df[num_cols]
# Out:
#         visitors  holiday   latitude   longitude  reserve_visitors
# 0             25        0  35.658068  139.751599               NaN
# 1             32        0  35.658068  139.751599               NaN
# 2             29        0  35.658068  139.751599               NaN
# 3             22        0  35.658068  139.751599               NaN
# 4              6        0  35.658068  139.751599               NaN
# ...          ...      ...        ...         ...               ...
# 252103        49        0  34.695124  135.197852               6.0
# 252104        60        0  34.695124  135.197852              37.0
# 252105        69        0  34.695124  135.197852              35.0
# 252106        31        1  34.695124  135.197852               3.0
# 252107        26        0  34.695124  135.197852              32.0
#
# [252108 rows x 5 columns]

# %%
df[num_cols].fillna(0)
# Out:
#         visitors  holiday   latitude   longitude  reserve_visitors
# 0             25        0  35.658068  139.751599               0.0
# 1             32        0  35.658068  139.751599               0.0
# 2             29        0  35.658068  139.751599               0.0
# 3             22        0  35.658068  139.751599               0.0
# 4              6        0  35.658068  139.751599               0.0
# ...          ...      ...        ...         ...               ...
# 252103        49        0  34.695124  135.197852               6.0
# 252104        60        0  34.695124  135.197852              37.0
# 252105        69        0  34.695124  135.197852              35.0
# 252106        31        1  34.695124  135.197852               3.0
# 252107        26        0  34.695124  135.197852              32.0
#
# [252108 rows x 5 columns]

# %%
df[num_cols].mean()
# Out:
# visitors             20.973761
# holiday               0.050673
# latitude             35.613121
# longitude           137.357865
# reserve_visitors     16.699808
# dtype: float64

# %%
##pass the above expression in as the answer
df[num_cols].fillna(df[num_cols].mean())
# Out:
#         visitors  holiday   latitude   longitude  reserve_visitors
# 0             25        0  35.658068  139.751599         16.699808
# 1             32        0  35.658068  139.751599         16.699808
# 2             29        0  35.658068  139.751599         16.699808
# 3             22        0  35.658068  139.751599         16.699808
# 4              6        0  35.658068  139.751599         16.699808
# ...          ...      ...        ...         ...               ...
# 252103        49        0  34.695124  135.197852          6.000000
# 252104        60        0  34.695124  135.197852         37.000000
# 252105        69        0  34.695124  135.197852         35.000000
# 252106        31        1  34.695124  135.197852          3.000000
# 252107        26        0  34.695124  135.197852         32.000000
#
# [252108 rows x 5 columns]

# %%
df['visit_date']
# Out:
# 0         2016-01-13
# 1         2016-01-14
# 2         2016-01-15
# 3         2016-01-16
# 4         2016-01-18
#              ...
# 252103    2017-04-21
# 252104    2017-04-22
# 252105    2017-03-26
# 252106    2017-03-20
# 252107    2017-04-09
# Name: visit_date, Length: 252108, dtype: object

# %%
df[df['visit_date'].between('2016-01-01','2017-01-01')]
##All rows where condition is true
# Out:
#                           id  visit_date  visitors day_of_week  holiday  \
# 0       air_ba937bf13d40fb24  2016-01-13        25   Wednesday        0
# 1       air_ba937bf13d40fb24  2016-01-14        32    Thursday        0
# 2       air_ba937bf13d40fb24  2016-01-15        29      Friday        0
# 3       air_ba937bf13d40fb24  2016-01-16        22    Saturday        0
# 4       air_ba937bf13d40fb24  2016-01-18         6      Monday        0
# ...                      ...         ...       ...         ...      ...
# 251318  air_31c753b48a657b6c  2016-12-29        23    Thursday        1
# 251403  air_31c753b48a657b6c  2016-12-18        34      Sunday        0
# 251409  air_31c753b48a657b6c  2016-12-25        36      Sunday        0
# 251410  air_31c753b48a657b6c  2016-12-30        18      Friday        1
# 251499  air_7420042ff75f9aca  2016-11-27         1      Sunday        0
#
#                                genre                           area  \
# ...

# %%
df['visit_date'].dt.quarter
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-131-a7076ea3c1ff> in <module>
# ----> 1 df['visit_date'].dt.quarter
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
#     181         # Replace the property with the accessor object. Inspired by:
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 252108 entries, 0 to 252107
# Data columns (total 10 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   id                252108 non-null  object
#  1   visit_date        252108 non-null  object
#  2   visitors          252108 non-null  int64
#  3   day_of_week       252108 non-null  object
#  4   holiday           252108 non-null  int64
#  5   genre             252108 non-null  object
#  6   area              252108 non-null  object
#  7   latitude          252108 non-null  float64
#  8   longitude         252108 non-null  float64
#  9   reserve_visitors  108394 non-null  float64
# dtypes: float64(3), int64(2), object(5)
# memory usage: 19.2+ MB

# %%
df['visit_date'] = pd.to_datetime(df['visit_date'])

# %%
df['visit_date'].dt.quarter
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 252103    2
# 252104    2
# 252105    1
# 252106    1
# 252107    2
# Name: visit_date, Length: 252108, dtype: int64

# %%
##broadcasting in pandas/numpy
df['new_col'] = 1

# %%
df['new_col'] = np.random.normal(size = 252108)

# %%
df
# Out:
#                           id visit_date  visitors day_of_week  holiday  \
# 0       air_ba937bf13d40fb24 2016-01-13        25   Wednesday        0
# 1       air_ba937bf13d40fb24 2016-01-14        32    Thursday        0
# 2       air_ba937bf13d40fb24 2016-01-15        29      Friday        0
# 3       air_ba937bf13d40fb24 2016-01-16        22    Saturday        0
# 4       air_ba937bf13d40fb24 2016-01-18         6      Monday        0
# ...                      ...        ...       ...         ...      ...
# 252103  air_a17f0778617c76e2 2017-04-21        49      Friday        0
# 252104  air_a17f0778617c76e2 2017-04-22        60    Saturday        0
# 252105  air_a17f0778617c76e2 2017-03-26        69      Sunday        0
# 252106  air_a17f0778617c76e2 2017-03-20        31      Monday        1
# 252107  air_a17f0778617c76e2 2017-04-09        26      Sunday        0
#
#                  genre                          area   latitude   longitude  \
# ...

# %%
np.where(df['visitors']==1)
# Out:
# (array([    61,    313,    359, ..., 251799, 251880, 251886]),)

# %%
expression = df['day_of_week'].isin(['Friday','Saturday','Sunday'])

# %%
df['PartOfWeek'] = np.where(expression, 'Weekend','Weekday')

# %%
df['PartOfWeek2'] = np.where(df['day_of_week'].isin(['Friday','Saturday','Sunday']), 'Weekend','Weekday')

# %%
df['quarter'] = df['visit_date'].dt.quarter

# %%
(df['quarter'].isin([2, 3])) & (df['PartOfWeek'] == 'Weekend')
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 252103     True
# 252104     True
# 252105    False
# 252106    False
# 252107     True
# Length: 252108, dtype: bool

# %%
conditions = [(df['quarter'].isin([2, 3])) & (df['PartOfWeek'] == 'Weekend'),
              (df['quarter'].isin([2, 3])) & (df['PartOfWeek'] == 'Weekday'),
              (df['quarter'].isin([1, 4])) & (df['PartOfWeek'] == 'Weekend'),
              (df['quarter'].isin([1, 4])) & (df['PartOfWeek'] == 'Weekday')
             ]
results    = [
    'Weekend Warm',
    'Weekday Warm',
    'Weekend Cold',
    'Weekday Cold'
]

# %%
df['WeatherPart'] = np.select(conditions, results, 'Other')

# %%
if 

elif

elif

elif

else

# %%
df.head()
# Out:
#                      id visit_date  visitors day_of_week  holiday       genre  \
# 0  air_ba937bf13d40fb24 2016-01-13        25   Wednesday        0  Dining bar
# 1  air_ba937bf13d40fb24 2016-01-14        32    Thursday        0  Dining bar
# 2  air_ba937bf13d40fb24 2016-01-15        29      Friday        0  Dining bar
# 3  air_ba937bf13d40fb24 2016-01-16        22    Saturday        0  Dining bar
# 4  air_ba937bf13d40fb24 2016-01-18         6      Monday        0  Dining bar
#
#                            area   latitude   longitude  reserve_visitors  \
# 0  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 1  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 2  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 3  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 4  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
#
#     new_col PartOfWeek PartOfWeek2  quarter   WeatherPart
# ...

# %%
df
# Out:
#                           id visit_date  visitors day_of_week  holiday  \
# 0       air_ba937bf13d40fb24 2016-01-13        25   Wednesday        0
# 1       air_ba937bf13d40fb24 2016-01-14        32    Thursday        0
# 2       air_ba937bf13d40fb24 2016-01-15        29      Friday        0
# 3       air_ba937bf13d40fb24 2016-01-16        22    Saturday        0
# 4       air_ba937bf13d40fb24 2016-01-18         6      Monday        0
# ...                      ...        ...       ...         ...      ...
# 252103  air_a17f0778617c76e2 2017-04-21        49      Friday        0
# 252104  air_a17f0778617c76e2 2017-04-22        60    Saturday        0
# 252105  air_a17f0778617c76e2 2017-03-26        69      Sunday        0
# 252106  air_a17f0778617c76e2 2017-03-20        31      Monday        1
# 252107  air_a17f0778617c76e2 2017-04-09        26      Sunday        0
#
#                  genre                          area   latitude   longitude  \
# ...

# %%
def clean_area_text(area_text):
    return area_text.replace('-', ' ').lower()

# %%
clean_area_text('Tokyo-ken Kobe shi-Kumoidori')
# Out:
# 'tokyo ken kobe shi kumoidori'

# %%
df['area'].apply(clean_area_text)
#goes through each row and applies function to colummn, goes slower
# Out:
# 0         tōkyō to minato ku shibakōen
# 1         tōkyō to minato ku shibakōen
# 2         tōkyō to minato ku shibakōen
# 3         tōkyō to minato ku shibakōen
# 4         tōkyō to minato ku shibakōen
#                       ...
# 252103    hyōgo ken kōbe shi kumoidōri
# 252104    hyōgo ken kōbe shi kumoidōri
# 252105    hyōgo ken kōbe shi kumoidōri
# 252106    hyōgo ken kōbe shi kumoidōri
# 252107    hyōgo ken kōbe shi kumoidōri
# Name: area, Length: 252108, dtype: object

# %%
df['day_of_week'].isin(["Friday", "Saturday"])
# Out:
# 0         False
# 1         False
# 2          True
# 3          True
# 4         False
#           ...
# 252103     True
# 252104     True
# 252105    False
# 252106    False
# 252107    False
# Name: day_of_week, Length: 252108, dtype: bool

# %%
df['Weekend'] = df['day_of_week'].isin(["Friday", "Saturday"])

# %%
df.head()
# Out:
#                      id  visit_date  visitors day_of_week  holiday  \
# 0  air_ba937bf13d40fb24  2016-01-13        25   Wednesday        0
# 1  air_ba937bf13d40fb24  2016-01-14        32    Thursday        0
# 2  air_ba937bf13d40fb24  2016-01-15        29      Friday        0
# 3  air_ba937bf13d40fb24  2016-01-16        22    Saturday        0
# 4  air_ba937bf13d40fb24  2016-01-18         6      Monday        0
#
#         genre                          area   latitude   longitude  \
# 0  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 1  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 2  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 3  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# 4  Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
#
#    reserve_visitors  Weekend
# 0               NaN    False
# 1               NaN    False
# 2               NaN     True
# 3               NaN     True
# ...

# %%
df['reserve_visitors'].quantile(0.25)
# Out:
# 4.0

# %%
df['reserve_visitors'].quantile(.5)
# Out:
# 10.0

# %%
df['reserve_visitors'].quantile(.75)
# Out:
# 24.0

# %%
conditions = [(df['reserve_visitors'] <= 4.0),
              ((df['reserve_visitors'] > 4.0) & (df['reserve_visitors'] < 24)),
              (df['reserve_visitors'] >= 24)
             ]
results    = [
    'Low',
    'Medium',
    'High'
]

# %%
df['Reservation_Activity'] = np.select(conditions, results, 'N/A')

# %%
df.head(100)
# Out:
#                       id  visit_date  visitors day_of_week  holiday  \
# 0   air_ba937bf13d40fb24  2016-01-13        25   Wednesday        0
# 1   air_ba937bf13d40fb24  2016-01-14        32    Thursday        0
# 2   air_ba937bf13d40fb24  2016-01-15        29      Friday        0
# 3   air_ba937bf13d40fb24  2016-01-16        22    Saturday        0
# 4   air_ba937bf13d40fb24  2016-01-18         6      Monday        0
# ..                   ...         ...       ...         ...      ...
# 95  air_ba937bf13d40fb24  2016-05-10        14     Tuesday        0
# 96  air_ba937bf13d40fb24  2016-05-11        24   Wednesday        0
# 97  air_ba937bf13d40fb24  2016-05-12        30    Thursday        0
# 98  air_ba937bf13d40fb24  2016-05-13        45      Friday        0
# 99  air_ba937bf13d40fb24  2016-05-14        48    Saturday        0
#
#          genre                          area   latitude   longitude  \
# 0   Dining bar  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599
# ...

# %%
df['visit_date'].max()
# Out:
# '2017-04-22'

# %%
df['visit_date'].min()
# Out:
# '2016-01-01'

# %%
df['visit_date'] = df['visit_date'].dt
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-22-f497839adc45> in <module>
# ----> 1 df['visit_date'] = df['visit_date'].dt
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/generic.py in __getattr__(self, name)
#    5459             or name in self._accessors
#    5460         ):
# -> 5461             return object.__getattribute__(self, name)
#    5462         else:
#    5463             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/accessor.py in __get__(self, obj, cls)
#     178             # we're accessing the attribute of the class, i.e., Dataset.geo
#     179             return self._accessor
# --> 180         accessor_obj = self._accessor(obj)
#     181         # Replace the property with the accessor object. Inspired by:
# ...

# %%
df['visit_date'] = pd.to_datetime(df['visit_date'])

# %%
df['visit_date'].max() - df['visit_date'].min()
# Out:
# Timedelta('477 days 00:00:00')

# %%
df['days'] = df['visit_date'] - df['visit_date'].min()
df['days'] = df['days'].dt.days

# %%
df.head()
# Out:
#                      id visit_date  visitors day_of_week  holiday       genre  \
# 0  air_ba937bf13d40fb24 2016-01-13        25   Wednesday        0  Dining bar
# 1  air_ba937bf13d40fb24 2016-01-14        32    Thursday        0  Dining bar
# 2  air_ba937bf13d40fb24 2016-01-15        29      Friday        0  Dining bar
# 3  air_ba937bf13d40fb24 2016-01-16        22    Saturday        0  Dining bar
# 4  air_ba937bf13d40fb24 2016-01-18         6      Monday        0  Dining bar
#
#                            area   latitude   longitude  reserve_visitors  \
# 0  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 1  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 2  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 3  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 4  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
#
#    Weekend Reservation_Activity    days
# ...

# %%
df['days'] = df['days'].dt.days

# %%
df.head()
# Out:
#                      id visit_date  visitors day_of_week  holiday       genre  \
# 0  air_ba937bf13d40fb24 2016-01-13        25   Wednesday        0  Dining bar
# 1  air_ba937bf13d40fb24 2016-01-14        32    Thursday        0  Dining bar
# 2  air_ba937bf13d40fb24 2016-01-15        29      Friday        0  Dining bar
# 3  air_ba937bf13d40fb24 2016-01-16        22    Saturday        0  Dining bar
# 4  air_ba937bf13d40fb24 2016-01-18         6      Monday        0  Dining bar
#
#                            area   latitude   longitude  reserve_visitors  \
# 0  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 1  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 2  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 3  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
# 4  Tōkyō-to Minato-ku Shibakōen  35.658068  139.751599               NaN
#
#    Weekend Reservation_Activity  days
# ...

# %%
cd /Users/mcs275/dat-11-15/ClassMaterial/Unit1/data
# Out:
# /Users/mcs275/dat-11-15/ClassMaterial/Unit1/data

# %%
# Out:
# master.csv

# %%
df = pd.read_csv('/Users/mcs275/dat-11-15/ClassMaterial/Unit1/data/master.csv')
